# %% [markdown]
# ## OMOP Attribute Study
# Purpose: This notebook merges two datasets containing OMOP field definitions
#
#
# - omop_gpt.csv: Contains OMOP field definitions from GPT
# - omop_fields_claude: Contains OMOP field definitions from Claude
#
# The datasets are merged on the common field identifier column to create a comprehensive
# mapping of OMOP fields with information from both sources.

# %%
import pandas as pd

# %%
DATA_INPUT_PATH = "/home/paula/Documentos/pmorenofajardo87/NOCTUAMED/noctuamed_rafa/transmisiones_a_csv/transmisiones_anonimizadas_gem/estandarizados/omop_standardized_data.csv"

# %%
omop_gpt = pd.read_csv("OMOP_fields_gpt.csv")
omop_claude = pd.read_csv("OMOP_fields_claude.csv")
omop_standardized_data = pd.read_csv(DATA_INPUT_PATH)

# %%
# Rename the first column in omop_claude to match omop_gpt for merging
omop_claude = omop_claude.rename(columns={"Campo": "OMOP Field"})

# Merge the two dataframes on the "OMOP Field" column
merged_df = pd.merge(
    omop_gpt, 
    omop_claude, 
    on="OMOP Field", 
    how="outer",  # Use outer join to keep all rows from both dataframes
    suffixes=('_gpt', '_claude')  # Add suffixes to distinguish columns with the same name
)

# Display the first few rows of the merged dataframe
print(f"Merged dataframe shape: {merged_df.shape}")
merged_df.head()
# Out:
# Merged dataframe shape: (81, 10)
#                OMOP Field           Descripción_gpt Tabla OMOP sugerida  \
# 0             CLINIC_NAME      Nombre de la clínica    VISIT_OCCURRENCE
# 1   MANUFACTURER_PRIORITY  Prioridad del fabricante     DEVICE_EXPOSURE
# 2  MDC_IDC_DEV_IMPLANT_DT     Fecha de implantación     DEVICE_EXPOSURE
# 3         MDC_IDC_DEV_MFG                       NaN                 NaN
# 4       MDC_IDC_DEV_MODEL                       NaN                 NaN
#
#    Tipo de dato_gpt Rango esperado / Observaciones  \
# 0            string       Nombre del centro médico
# 1  string / ordinal    Interno; sin rango definido
# 2              date                   Fecha válida
# 3               NaN                            NaN
# 4               NaN                            NaN
#
#                   Significado Tipo de dato_claude Unidad  \
# 0        Nombre de la clínica             Varchar    NaN
# 1    Prioridad del fabricante     Varchar/Integer    NaN
# 2           Fecha de implante                Date    NaN
# 3  Fabricante del dispositivo             Varchar    NaN
# 4      Modelo del dispositivo             Varchar    NaN
#
#                            Descripción_claude  \
# 0  Centro médico donde se realiza seguimiento
# 1         Nivel de prioridad según fabricante
# 2     Fecha en que se implantó el dispositivo
# 3          Empresa fabricante del dispositivo
# 4           Modelo específico del dispositivo
#
#                                     Observaciones
# 0          Ubicación de la consulta o seguimiento
# 1              Puede indicar urgencia de revisión
# 2             Importante para calcular longevidad
# 3  Ej: "Medtronic", "Boston Scientific", "Abbott"
# 4            Código o nombre del modelo comercial

# %%
# Save the merged dataframe to a new CSV file
merged_df.to_csv("OMOP_fields_merged.csv", index=False, header=True)
print("Merged dataframe saved to 'OMOP_fields_merged.csv'")
# Out:
# Merged dataframe saved to 'OMOP_fields_merged.csv'

# %%
# Analyze the merge results
print(f"Number of rows in omop_gpt: {len(omop_gpt)}")
print(f"Number of rows in omop_claude: {len(omop_claude)}")
print(f"Number of rows in merged_df: {len(merged_df)}")

# Check which fields are in one dataset but not the other
gpt_only = set(omop_gpt["OMOP Field"]) - set(omop_claude["OMOP Field"])
claude_only = set(omop_claude["OMOP Field"]) - set(omop_gpt["OMOP Field"])
common_fields = set(omop_gpt["OMOP Field"]) & set(omop_claude["OMOP Field"])

print(f"\nNumber of fields only in GPT dataset: {len(gpt_only)}")
print(f"Number of fields only in Claude dataset: {len(claude_only)}")
print(f"Number of fields common to both datasets: {len(common_fields)}")

# Display fields that are only in one dataset
if len(gpt_only) > 0:
    print("\nFields only in GPT dataset:")
    for field in sorted(gpt_only):
        print(f"- {field}")

if len(claude_only) > 0:
    print("\nFields only in Claude dataset:")
    for field in sorted(claude_only):
        print(f"- {field}")
# Out:
# Number of rows in omop_gpt: 61
# Number of rows in omop_claude: 80
# Number of rows in merged_df: 81
#
# Number of fields only in GPT dataset: 0
# Number of fields only in Claude dataset: 20
# Number of fields common to both datasets: 60
#
# Fields only in Claude dataset:
# - MDC_IDC_DEV_MFG
# - MDC_IDC_DEV_MODEL
# - MDC_IDC_DEV_SERIAL
# - MDC_IDC_DEV_TYPE
# - MDC_IDC_MSMT_BATTERY_DTM
# - MDC_IDC_MSMT_BATTERY_REMAINING_LONGEVITY
# - MDC_IDC_MSMT_BATTERY_RRT_TRIGGER
# - MDC_IDC_MSMT_BATTERY_STATUS
# - MDC_IDC_MSMT_BATTERY_VOLTAGE
# - MDC_IDC_MSMT_LEADCHNL_LV_IMPEDANCE_VALUE
# - MDC_IDC_MSMT_LEADCHNL_RV_IMPEDANCE_VALUE
# - MDC_IDC_SESS_DTM
# - MDC_IDC_SESS_TYPE
# - MDC_IDC_SET_BRADY_AV_DELAY_HIGH
# - MDC_IDC_SET_BRADY_AV_DELAY_LOW
# - MDC_IDC_SET_BRADY_HYSTRATE
# - MDC_IDC_SET_BRADY_MAX_SENSOR_RATE
# - MDC_IDC_SET_BRADY_MAX_TRACKING_RATE
# - MDC_IDC_SET_BRADY_MODE
# - MDC_IDC_STAT_TACHYTHERAPY_SHOCKS_DELIVERED_RECENT

# %%
print("data types in gpt")
print(set(merged_df['Tipo de dato_gpt'].to_list()))
print("data types in claude")
print(set(merged_df['Tipo de dato_claude'].to_list()))
print("number of fields data types  recognyzed by chat gpt:")
print(len(merged_df['Tipo de dato_gpt'].dropna()))
print("number of fields data types  recognyzed by chat gpt:")
print(len(merged_df['Tipo de dato_claude'].dropna()))
# Out:
# data types in gpt
# {'numeric', 'date', 'string / ordinal', nan, 'string / concept_id', 'integer', 'string', 'datetime'}
# data types in claude
# {'Varchar/Integer', 'Varchar', 'Integer', 'Datetime', 'Boolean', 'Date', 'Numeric'}
# number of fields data types  recognyzed by chat gpt:
# 61
# number of fields data types  recognyzed by chat gpt:
# 81

# %%
merged_df[merged_df['Tipo de dato_claude'] == 'Varchar']
# Out:
#                                       OMOP Field            Descripción_gpt  \
# 0                                    CLINIC_NAME       Nombre de la clínica
# 3                                MDC_IDC_DEV_MFG                        NaN
# 4                              MDC_IDC_DEV_MODEL                        NaN
# 5                             MDC_IDC_DEV_SERIAL                        NaN
# 6                               MDC_IDC_DEV_TYPE                        NaN
# 11                   MDC_IDC_MSMT_BATTERY_STATUS                        NaN
# 14  MDC_IDC_MSMT_LEADCHNL_LV_LEAD_CHANNEL_STATUS            Estado canal LV
# 19  MDC_IDC_MSMT_LEADCHNL_RA_LEAD_CHANNEL_STATUS            Estado canal RA
# 24  MDC_IDC_MSMT_LEADCHNL_RV_LEAD_CHANNEL_STATUS            Estado canal RV
# 29                             MDC_IDC_SESS_TYPE                        NaN
# 36                        MDC_IDC_SET_BRADY_MODE                        NaN
# 38       MDC_IDC_SET_LEADCHNL_LV_PACING_POLARITY  Polaridad estimulación LV
# 40      MDC_IDC_SET_LEADCHNL_LV_SENSING_POLARITY       Polaridad sensado LV
# 43       MDC_IDC_SET_LEADCHNL_RA_PACING_POLARITY  Polaridad estimulación RA
# 45      MDC_IDC_SET_LEADCHNL_RA_SENSING_POLARITY       Polaridad sensado RA
# 48       MDC_IDC_SET_LEADCHNL_RV_PACING_POLARITY  Polaridad estimulación RV
# 50      MDC_IDC_SET_LEADCHNL_RV_SENSING_POLARITY       Polaridad sensado RV
# 53                         MDC_IDC_SET_ZONE_TYPE  Tipo de zona de detección
# 79                                     PT_GENDER        Género del paciente
# 80                                       PT_NAME        Nombre del paciente
#
#    Tabla OMOP sugerida     Tipo de dato_gpt  \
# 0     VISIT_OCCURRENCE               string
# 3                  NaN                  NaN
# 4                  NaN                  NaN
# 5                  NaN                  NaN
# 6                  NaN                  NaN
# 11                 NaN                  NaN
# 14         OBSERVATION               string
# 19         OBSERVATION               string
# 24         OBSERVATION               string
# 29                 NaN                  NaN
# 36                 NaN                  NaN
# 38         OBSERVATION               string
# 40         OBSERVATION               string
# 43         OBSERVATION               string
# 45         OBSERVATION               string
# 48         OBSERVATION               string
# 50         OBSERVATION               string
# 53         OBSERVATION               string
# 79              PERSON  string / concept_id
# 80              PERSON               string
#
#                Rango esperado / Observaciones  \
# 0                    Nombre del centro médico
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 11                                        NaN
# 14                          OK, fallo, alerta
# 19                          OK, fallo, alerta
# 24                          OK, fallo, alerta
# 29                                        NaN
# 36                                        NaN
# 38                           Unipolar/Bipolar
# 40                           Unipolar/Bipolar
# 43                           Unipolar/Bipolar
# 45                           Unipolar/Bipolar
# 48                           Unipolar/Bipolar
# 50                           Unipolar/Bipolar
# 53                               VT, VF, etc.
# 79  M/F/Other o mapeado a concept_id estándar
# 80               Nombre completo del paciente
#
#                                         Significado Tipo de dato_claude  \
# 0                              Nombre de la clínica             Varchar
# 3                        Fabricante del dispositivo             Varchar
# 4                            Modelo del dispositivo             Varchar
# 5                                   Número de serie             Varchar
# 6                               Tipo de dispositivo             Varchar
# 11                             Estado de la batería             Varchar
# 14       Estado del electrodo ventricular izquierdo             Varchar
# 19           Estado del electrodo auricular derecho             Varchar
# 24         Estado del electrodo ventricular derecho             Varchar
# 29                                   Tipo de sesión             Varchar
# 36             Modo de estimulación antibradicardia             Varchar
# 38  Polaridad de estimulación ventricular izquierda             Varchar
# 40     Polaridad de detección ventricular izquierda             Varchar
# 43      Polaridad de estimulación auricular derecha             Varchar
# 45         Polaridad de detección auricular derecha             Varchar
# 48    Polaridad de estimulación ventricular derecha             Varchar
# 50       Polaridad de detección ventricular derecha             Varchar
# 53                      Tipo de zona de taquicardia             Varchar
# 79                              Género del paciente             Varchar
# 80                              Nombre del paciente             Varchar
#
#    Unidad                                 Descripción_claude  \
# 0     NaN         Centro médico donde se realiza seguimiento
# 3     NaN                 Empresa fabricante del dispositivo
# 4     NaN                  Modelo específico del dispositivo
# 5     NaN     Número único de identificación del dispositivo
# 6     NaN               Categoría del dispositivo implantado
# 11    NaN                        Estado actual de la batería
# 14    NaN  Estado funcional del electrodo ventricular izq...
# 19    NaN           Estado funcional del electrodo auricular
# 24    NaN  Estado funcional del electrodo ventricular der...
# 29    NaN        Categoría de la sesión (presencial, remota)
# 36    NaN                    Modo de estimulación programado
# 38    NaN  Configuración de polaridad para estimulación v...
# 40    NaN  Configuración de polaridad para detección vent...
# 43    NaN  Configuración de polaridad para estimulación a...
# 45    NaN  Configuración de polaridad para detección auri...
# 48    NaN  Configuración de polaridad para estimulación v...
# 50    NaN  Configuración de polaridad para detección vent...
# 53    NaN  Categoría de la zona de detección de taquiarri...
# 79    NaN               Sexo biológico o género del paciente
# 80    NaN                       Nombre completo del paciente
#
#                                         Observaciones
# 0              Ubicación de la consulta o seguimiento
# 3      Ej: "Medtronic", "Boston Scientific", "Abbott"
# 4                Código o nombre del modelo comercial
# 5                  Identificador único del fabricante
# 6            Ej: "ICD", "CRT-D", "Pacemaker", "CRT-P"
# 11  Ej: "Normal", "ERI" (Elective Replacement Indi...
# 14                  Ej: "Normal", "Noise", "Fracture"
# 19                  Ej: "Normal", "Noise", "Fracture"
# 24                  Ej: "Normal", "Noise", "Fracture"
# 29            Ej: "In-clinic", "Remote", "Ambulatory"
# 36                    Ej: "DDD", "VVI", "AAI", "DDDR"
# 38                          Ej: "Bipolar", "Unipolar"
# 40                          Ej: "Bipolar", "Unipolar"
# 43                          Ej: "Bipolar", "Unipolar"
# 45                          Ej: "Bipolar", "Unipolar"
# 48                          Ej: "Bipolar", "Unipolar"
# 50                          Ej: "Bipolar", "Unipolar"
# 53                        Ej: "VT", "VF", "SVT", "AF"
# 79     Típicamente "M", "F" u otros valores definidos
# 80    Datos demográficos e información identificativa

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import pandas as pd

# Lista de campos únicos para el desplegable
field_options = merged_df['OMOP Field'].unique().tolist()

# Crear el desplegable
field_dropdown = widgets.Dropdown(
    options=field_options,
    value='MDC_IDC_DEV_MODEL',
    description='Selecciona un campo:',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='50%')
)

# Crear un contenedor para mostrar resultados
output = widgets.Output()

# Función de actualización
def update_field_info(change):
    with output:
        clear_output()  # Limpia la salida anterior
        selected_field = change['new']
        field_info = merged_df[merged_df['OMOP Field'] == selected_field].iloc[0]  # conserva formato DataFrame
        display(field_info)

# Ejecutar la función por defecto una vez
update_field_info({'new': field_dropdown.value})

# Vincular el cambio del desplegable
field_dropdown.observe(update_field_info, names='value')

# Mostrar los widgets
display(field_dropdown, output)
# Out:
# Dropdown(description='Selecciona un campo:', index=4, layout=Layout(width='50%'), options=('CLINIC_NAME', 'MAN…
# Output()

# %%
manufacturer_code = omop_standardized_data["manufacturer_code"].unique()
samples = []
for i in manufacturer_code:
    sample = omop_standardized_data[omop_standardized_data["manufacturer_code"] == i].sample(3)
    samples.append(sample)
samples_df = pd.concat(samples, ignore_index=True)
display(samples_df)
# Out:
#                                           source_file     manufacturer_code  \
# 0                              p1_abbott/85204094.hl7             p1_abbott
# 1                              p1_abbott/84999858.hl7             p1_abbott
# 2                              p1_abbott/85204093.hl7             p1_abbott
# 3   p2_biotronik/a16aca36-6bc1-4de3-9b48-9519e1bac...          p2_biotronik
# 4   p2_biotronik/04f8bd87-b57c-475f-9253-23ab6dd2a...          p2_biotronik
# 5   p2_biotronik/02337735-94b9-4022-9a24-549b39e4c...          p2_biotronik
# 6                 p3_boston_scientific/1010566883.hl7  p3_boston_scientific
# 7                 p3_boston_scientific/1010568115.hl7  p3_boston_scientific
# 8                 p3_boston_scientific/1010568115.hl7  p3_boston_scientific
# 9   p4_medtronic/D2177F36-B81B-4359-B883-3A6912DB7...          p4_medtronic
# 10  p4_medtronic/2527C137-8CBA-499C-AA8B-970DCBBD4...          p4_medtronic
# 11  p4_medtronic/D2177F36-B81B-4359-B883-3A6912DB7...          p4_medtronic
# 12                           p5_microport/1033887.xml          p5_microport
# 13                           p5_microport/1000352.xml          p5_microport
# 14                           p5_microport/1000352.xml          p5_microport
#
#                                           CLINIC_NAME MANUFACTURER_PRIORITY  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                   NaN
# 2                                                 NaN                   NaN
# 3   Hospital Universitario de Gran Canaria Dr. Negrin              Amarillo
# 4   Hospital Universitario de Gran Canaria Dr. Negrin              Amarillo
# 5   Hospital Universitario de Gran Canaria Dr. Negrin              Amarillo
# 6                                                 NaN                   NaN
# 7                                                 NaN                   NaN
# 8                                                 NaN                   NaN
# 9                                                 NaN                   NaN
# 10                                                NaN                   NaN
# 11                                                NaN                   NaN
# 12                                                NaN                   NaN
# 13                                                NaN                   NaN
# 14                                                NaN                   NaN
#
#              MDC_IDC_SESS_DTM MDC_IDC_SESS_TYPE MDC_IDC_DEV_TYPE  \
# 0              20250325060035   RemoteScheduled              IPG
# 1              20250311040016   RemoteScheduled              IPG
# 2              20250318055721   RemoteScheduled              IPG
# 3        20250117T223153+0000            Remote              IPG
# 4        20250223T220731+0000            Remote              IPG
# 5        20250327T004916+0000            Remote              IPG
# 6         20250403215000+0000               NaN            S-ICD
# 7         20250403233400+0000               NaN              DAI
# 8         20250403233400+0000               NaN              DAI
# 9         20220703083846+0000            Remote        Pacemaker
# 10        20220708115926+0000            Remote        Pacemaker
# 11        20220703083846+0000            Remote        Pacemaker
# 12  2024-10-08T01:04:30+02:00               NaN              ICD
# 13  2024-09-02T02:17:49+02:00               NaN              ICD
# 14  2024-09-02T02:17:49+02:00               NaN              ICD
#
#       MDC_IDC_DEV_MFG      MDC_IDC_DEV_MODEL MDC_IDC_DEV_SERIAL  ...  \
# 0              Abbott  2272 Assurity MRI(TM)            6700726  ...
# 1              Abbott  2272 Assurity MRI(TM)            6700726  ...
# 2              Abbott  2272 Assurity MRI(TM)            6700726  ...
# 3           Biotronik          Enitra 6 SR-T           69986066  ...
# 4           Biotronik          Enitra 6 SR-T         1000096403  ...
# 5           Biotronik           Epyra 6 SR-T           68948906  ...
# 6   Boston Scientific       EMBLEM MRI S-ICD             140574  ...
# 7   Boston Scientific        VIGILANT EL ICD             619014  ...
# 8   Boston Scientific        VIGILANT EL ICD             619014  ...
# 9           Medtronic                 ADDR01         NWB871343S  ...
# 10          Medtronic                 ADDR01         NWB083596G  ...
# 11          Medtronic                 ADDR01         NWB871343S  ...
# 12          Microport       ULYS DF4 DR 2540           221DU181  ...
# 13          Microport   TALENTIA DF4 VR 3240           317JQ035  ...
# 14          Microport   TALENTIA DF4 VR 3240           317JQ035  ...
#
#    MDC_IDC_STAT_TACHYTHERAPY_SHOCKS_DELIVERED_TOTAL  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
#
#    MDC_IDC_STAT_TACHYTHERAPY_SHOCKS_ABORTED_TOTAL  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
#
#    MDC_IDC_STAT_TACHYTHERAPY_ATP_DELIVERED_TOTAL  MDC_IDC_STAT_AT_DTM_START  \
# 0                                            NaN             20241214020617
# 1                                            NaN             20241214020524
# 2                                            NaN             20241214020551
# 3                                            NaN                        NaN
# 4                                            NaN                        NaN
# 5                                            NaN                        NaN
# 6                                            NaN                        NaN
# 7                                            NaN                        NaN
# 8                                            NaN                        NaN
# 9                                            NaN        20220408103245+0000
# 10                                           NaN        20210715115925+0000
# 11                                           NaN        20220408103245+0000
# 12                                           NaN                        NaN
# 13                                           NaN                        NaN
# 14                                           NaN                        NaN
#
#     MDC_IDC_STAT_AT_DTM_END  MDC_IDC_STAT_AT_BURDEN_PERCENT  \
# 0            20250325060139                             6.0
# 1            20250311040120                             7.0
# 2            20250318055825                             7.0
# 3                       NaN                             NaN
# 4                       NaN                             NaN
# 5                       NaN                             NaN
# 6                       NaN                             NaN
# 7                       NaN                             NaN
# 8                       NaN                             NaN
# 9       20220703083846+0000                             0.0
# 10      20220708115926+0000                             0.1
# 11      20220703083846+0000                             0.0
# 12                      NaN                             NaN
# 13                      NaN                             NaN
# 14                      NaN                             NaN
#
#    MDC_IDC_STAT_AT_MODE_SW_COUNT MDC_IDC_STAT_AT_MODE_SW_MAX_DURATION  \
# 0                           23.0                             219202.0
# 1                           23.0                             219202.0
# 2                           23.0                             219202.0
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
# 5                            NaN                                  NaN
# 6                            NaN                                  NaN
# 7                            NaN                                  NaN
# 8                            NaN                                  NaN
# 9                            6.0                                  NaN
# 10                          48.0                                  NaN
# 11                           6.0                                  NaN
# 12                           NaN                                  NaN
# 13                           NaN                                  NaN
# 14                           NaN                                  NaN
#
#     patient_id_pid2                    patient_id_pid3
# 0               NaN  model:2272/serial:6700726, 332044
# 1               NaN  model:2272/serial:6700726, 332044
# 2               NaN  model:2272/serial:6700726, 332044
# 3               NaN                                NaN
# 4               NaN                                NaN
# 5               NaN                                NaN
# 6        1001412373                 1001412373, 171633
# 7        1001444771                 1001444771, 563566
# 8        1001444771                 1001444771, 563566
# 9                []                                 []
# 10               []                                 []
# 11               []                                 []
# 12              NaN                                NaN
# 13              NaN                                NaN
# 14              NaN                                NaN
#
# [15 rows x 81 columns]

# %%
# Date or dateTime OMOP fields
# Filtrar filas donde 'Tipo de dato_claude' o 'Tipo de dato_gpt' contienen 'date', 'datetime' o 'timestamp'
dates_fields = merged_df[
    (merged_df['Tipo de dato_claude'].str.strip().str.lower().isin(['date', 'datetime', 'timestamp'])) |
    (merged_df['Tipo de dato_gpt'].str.strip().str.lower().isin(['date', 'datetime', 'timestamp']))
    ]
dates_fields[['Tipo de dato_gpt','Tipo de dato_claude','Significado','Descripción_claude']]
# Out:
#    Tipo de dato_gpt Tipo de dato_claude  \
# 2              date                Date
# 7               NaN            Datetime
# 28              NaN            Datetime
# 55         datetime            Datetime
# 56         datetime            Datetime
# 69         datetime            Datetime
# 70         datetime            Datetime
# 76         datetime            Datetime
# 77         datetime            Datetime
# 78             date                Date
#
#                               Significado  \
# 2                       Fecha de implante
# 7     Fecha y hora de medición de batería
# 28                 Fecha y hora de sesión
# 55        Fin de período de evaluación AT
# 56     Inicio de período de evaluación AT
# 69     Fin de período reciente de terapia
# 70  Inicio de período reciente de terapia
# 76        Fin de período total de terapia
# 77     Inicio de período total de terapia
# 78                    Fecha de nacimiento
#
#                                    Descripción_claude
# 2             Fecha en que se implantó el dispositivo
# 7        Momento de la medición del estado de batería
# 28  Momento exacto de la interrogación del disposi...
# 55  Fecha y hora de fin para estadísticas de taqui...
# 56  Fecha y hora de inicio para estadísticas de ta...
# 69  Fecha y hora de fin del período reciente evaluado
# 70  Fecha y hora de inicio del período reciente ev...
# 76     Fecha y hora de fin del período total evaluado
# 77  Fecha y hora de inicio del período total evaluado
# 78                   Fecha de nacimiento del paciente

# %% [markdown]
# parece que claude ha funcionado mejor describiendo los campos fecha y tiempo

# %%
dates_omop_fields = dates_fields['OMOP Field'].to_list()
cols_existentes = [col for col in dates_omop_fields if col in samples_df.columns]
samples_df_dates = samples_df[cols_existentes]
print("Dataframe with samples with dates:")
samples_df_dates.sample(10)
# Out:
# Dataframe with samples with dates:
#    MDC_IDC_DEV_IMPLANT_DT MDC_IDC_MSMT_BATTERY_DTM           MDC_IDC_SESS_DTM  \
# 13             2024-06-03                      NaN  2024-09-02T02:17:49+02:00
# 6                20210729                      NaN        20250403215000+0000
# 2          20230321000000           20250317144939             20250318055721
# 11                    NaN      20220703083846+0000        20220703083846+0000
# 5         20180601T000000          20250327T012600       20250327T004916+0000
# 8                20220603                      NaN        20250403233400+0000
# 4         20231221T000000          20250224T012300       20250223T220731+0000
# 9                     NaN      20220703083846+0000        20220703083846+0000
# 14             2024-06-03                      NaN  2024-09-02T02:17:49+02:00
# 0          20230321000000           20250324075005             20250325060035
#
#    MDC_IDC_STAT_AT_DTM_END MDC_IDC_STAT_AT_DTM_START  \
# 13                     NaN                       NaN
# 6                      NaN                       NaN
# 2           20250318055825            20241214020551
# 11     20220703083846+0000       20220408103245+0000
# 5                      NaN                       NaN
# 8                      NaN                       NaN
# 4                      NaN                       NaN
# 9      20220703083846+0000       20220408103245+0000
# 14                     NaN                       NaN
# 0           20250325060139            20241214020617
#
#     MDC_IDC_STAT_TACHYTHERAPY_RECENT_DTM_END  \
# 13                                       NaN
# 6                                        NaN
# 2                               2.025032e+13
# 11                                       NaN
# 5                                        NaN
# 8                                        NaN
# 4                                        NaN
# 9                                        NaN
# 14                                       NaN
# 0                               2.025033e+13
#
#     MDC_IDC_STAT_TACHYTHERAPY_RECENT_DTM_START  \
# 13                                         NaN
# 6                                          NaN
# 2                                 2.024121e+13
# 11                                         NaN
# 5                                          NaN
# 8                                          NaN
# 4                                          NaN
# 9                                          NaN
# 14                                         NaN
# 0                                 2.024121e+13
#
#     MDC_IDC_STAT_TACHYTHERAPY_TOTAL_DTM_END  \
# 13                                      NaN
# 6                                       NaN
# 2                                       NaN
# 11                                      NaN
# 5                                       NaN
# 8                                       NaN
# 4                                       NaN
# 9                                       NaN
# 14                                      NaN
# 0                                       NaN
#
#     MDC_IDC_STAT_TACHYTHERAPY_TOTAL_DTM_START
# 13                                        NaN
# 6                                         NaN
# 2                                         NaN
# 11                                        NaN
# 5                                         NaN
# 8                                         NaN
# 4                                         NaN
# 9                                         NaN
# 14                                        NaN
# 0                                         NaN
